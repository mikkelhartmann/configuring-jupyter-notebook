# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Creating-a-figure" data-toc-modified-id="Creating-a-figure-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Creating a figure</a></span></li></ul></li></ul></div>

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction
# This is demo used to demonstrate the looks before and after using the customization. I will make this text a little longer so you can see how nice it looks with a bit of text.
#
# ## Creating a figure
# Now I will create a figure. Look at the difference in the quality of the inline figure. Notice that the figure is centered.

# %%
plt.style.use('my_mpl_style')

# %%
x = np.random.rand(100,3)
fig, ax = plt.subplots()
ax.plot(x, label='Some label');
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_title('The title');
